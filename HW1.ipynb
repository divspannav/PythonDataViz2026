# %% [markdown]
# <a href="https://colab.research.google.com/github/divspannav/PythonDataViz2026/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ศุภณัฏฐ์ ปุณมา

# %%
print('ID : 673020627-7')
# Out:
# ID : 673020627-7
