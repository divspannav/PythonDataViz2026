# %% [markdown]
# <a href="https://colab.research.google.com/github/divspannav/PythonDataViz2026/blob/main/HW1_(class_period_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### HW คำนวณเวลาเป็นวินาทีของเวลาต่อไปนี้โดยใช้คำสั่ง split() ช่วย (print ออกมาให้สวยงาม)
# 12:30:15
#
# 13:41:07
#
# 12:53:15
#
# 00:59:25
#
# 11:11:11
#
# 16:06:09

# %%
t = ['12:30:15','13:41:07','12:53:15','00:59:25','11:11:11','16:06:09']
print(t)
# Out:
# ['12:30:15', '13:41:07', '12:53:15', '00:59:25', '11:11:11', '16:06:09']

# %%
h,m,s = t[0].split(':')
total = int(h)*3600 + int(m)*60 + int(s)
print(total, 'sec')
# Out:
# 45015 sec

# %%
h,m,s = t[1].split(':')
total = int(h)*3600 + int(m)*60 + int(s)
print(total , 'sec')
# Out:
# 49267 sec

# %%
h,m,s = t[2].split(':')
total = int(h)*3600 + int(m)*60 + int(s)
print(total)
# Out:
# 46395

# %%
h,m,s = t[3].split(':')
total = int(h)*3600 + int(m)*60 + int(s)
print(total, 'sec')
# Out:
# 3565 sec

# %%
h,m,s = t[4].split(':')
total = int(h)*3600 + int(m)*60 + int(s)
print(total, 'sec')
# Out:
# 40271 sec

# %%
h,m,s = t[5].split(':')
total = int(h)*3600 + int(m)*60 + int(s)
print(total, 'sec')
# Out:
# 57969 sec
